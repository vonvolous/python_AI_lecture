# %% [markdown]
# <a href="https://colab.research.google.com/github/vonvolous/python_AI_lecture/blob/main/lecture_code/Py004_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Matplotlib**

# %% [markdown]
# ## **1. Matplotlib 개요**

# %% [markdown]
# ### 1-1. Matplotlib란?

# %% [markdown]
# - 파이썬에서 플롯(그래프)을 그릴 때 주로 쓰이는 2D, 3D 플롯팅 패키지(모듈)
# - 저명한 파이썬 라이브러리 개발자인 John Hunter에 의해 개발됨
# - 2003년 version 0.1이 발표된 이후 현재까지 꾸준히 발전해온 약 20년의 역사를 가진 패키지
# - 산업, 교육계에서 널리 쓰이는 수치해석 소프트웨어인 MATLAB과 유사한 사용자 인터페이스를 가지고 있어 각 업계에서 쉽게 접근 가능

# %% [markdown]
# ### 1-2. Matplotlib의 장점

# %% [markdown]
# - 동작하는 OS를 가리지 않음
# - 다양한 그래프와 그 구성요소에 대하여 상세한 서식을 설정 가능
# - 다양한 출력형식(PNG, SVG, JPG 등) 지원
# - MATLAB과 유사한 사용자 인터페이스

# %% [markdown]
# ### 1-3. 데이터 시각화

# %% [markdown]
# - 정보와 데이터를 그래프로 나타내는 것
# - 차트, 그래프, 맵과 같은 시각적 요소를 사용하여
# - 데이터에서 추세, 이상 값 및 패턴을 보고 이해할 수 있도록 해 주며
# - 데이터 분석에 쉽게 접근할 수 있도록 하는 방법
# - 특히 빅 데이터의 세계에서, 데이터 시각화 도구와 기술은 막대한 양의 정보를 분석하고 데이터 기반 의사 결정을 내리는 데에 필수적

# %% [markdown]
# ### 1-4. 데이터 시각화의 필요성

# %% [markdown]
# - 인간은 시력을 통해 얻는 정보양은 다른 기관의 정보보다 훨씬 많음
# - 지나치게 많은 데이터로 인해 이를 관리하고 이해하는 어려움이 계속해서 증가
# - 대부분의 사람들은 통계 데이터에 대해 잘 알지 못하며, 기본적인 통계 방법(평균, 중위수, 범위 등)은 인간의 인지적 성격과 맞지 않음
# - 통계 방법에 따라 규칙을 보는 것은 어렵지만, 데이터가 시각화되면 규칙은 매우 명확히 인지 가능(예: 안스콤비의 4중주)

# %% [markdown]
# <center><img src='https://raw.githubusercontent.com/aidalabs/Lectures/master/LectureFiles/images/Py004_Matplotlib_001.png' width="" height ="" /></center><br /><br />

# %% [markdown]
# ## **2. 환경설정**

# %%
import matplotlib.pyplot as plt

# %%
# 그래프를 그리기 위한 데이터 설정
x = [-3, -2, -1, 0, 1, 2, 3, 4, 5]
y = [3, 2, -1, 1, 0, -2, -1, 3, 1]

# %%
plt.figure(figsize=(8,4))
plt.title('오늘도 즐거운 하루', fontsize=20)
plt.scatter(x, y)
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.

# %% [markdown]
# - 쓸데없는 경고가 많이 나오는 문제

# %%
# warning메시지 무시
import warnings
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=(8,4))
plt.title('오늘도 즐거운 하루', fontsize=20)
plt.scatter(x, y)
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Malgun Gothic' not found.

# %% [markdown]
# - 한글이 깨지는 문제
#     - 이유: 한글 폰트가 설치되어 있지 않기 때문

# %%
# 현재 사용중인 폰트 확인
plt.rcParams['font.family']
# Out:
# ['Malgun Gothic']

# %%
# 한글폰트 설치하기 위해 필요한 모듈
import matplotlib.font_manager as fm

# %%
# 나눔바른고딕 폰트 설치 - 런타임 연결이 다시 될 때마다 다시 폰트를 설치해야 한글이 보인다.
# !apt install fonts-nanum

fm.fontManager.addfont('/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf')
plt.rcParams['font.family'] = "NanumBarunGothic"
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 16 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 1s (9,621 kB/s)
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 120511 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %%
plt.figure(figsize=(8,4))
plt.title('오늘도 즐거운 하루', fontsize=20)
plt.scatter(x, y)
plt.show()

# %% [markdown]
# - 갑자기 음수 부호(-)가 표시되지 않음
#     - 한글폰트와 유니코드의 음수 부호가 충돌을 일으키기 때문

# %%
# 마이너스(음수)부호 설정
plt.rc("axes", unicode_minus = False)

# %%
plt.figure(figsize=(8,4))
plt.title('오늘도 즐거운 하루', fontsize=20)
plt.scatter(x, y)
plt.show()

# %% [markdown]
# - 그래프를 그릴때 별도의 창이 열리고 그 위에서 그려지는 문제
#     - Colab을 이용하는 경우
#         - Colab은 기본적으로 현재 창에서 그래프가 그려지므로 따로 조치할 필요가 없음
#     - 개인 환경에서 Jupyter Notebook/Lab을 이용하는 경우
#         - %matplotlib inline 명령어를 통해서 해결 가능

# %%
# %matplotlib inline

# %% [markdown]
# ## **3. 그래프의 기본 구성**

# %% [markdown]
# <center><img src='https://raw.githubusercontent.com/aidalabs/Lectures/master/LectureFiles/images/Py004_Matplotlib_002.png' width="" height ="" /></center><br /><br />

# %% [markdown]
# ## **4. 기본 그래프 그리기**

# %%
import numpy as np

# %% [markdown]
# ### 4-1. Figure

# %% [markdown]
# - $-5 < x < 5$ , (x의 간격은 0.1)
# - $y_1=x^2+3$

# %%
x = np.arange(-5, 5, 0.1)
x
# Out:
# array([-5.00000000e+00, -4.90000000e+00, -4.80000000e+00, -4.70000000e+00,
#        -4.60000000e+00, -4.50000000e+00, -4.40000000e+00, -4.30000000e+00,
#        -4.20000000e+00, -4.10000000e+00, -4.00000000e+00, -3.90000000e+00,
#        -3.80000000e+00, -3.70000000e+00, -3.60000000e+00, -3.50000000e+00,
#        -3.40000000e+00, -3.30000000e+00, -3.20000000e+00, -3.10000000e+00,
#        -3.00000000e+00, -2.90000000e+00, -2.80000000e+00, -2.70000000e+00,
#        -2.60000000e+00, -2.50000000e+00, -2.40000000e+00, -2.30000000e+00,
#        -2.20000000e+00, -2.10000000e+00, -2.00000000e+00, -1.90000000e+00,
#        -1.80000000e+00, -1.70000000e+00, -1.60000000e+00, -1.50000000e+00,
#        -1.40000000e+00, -1.30000000e+00, -1.20000000e+00, -1.10000000e+00,
#        -1.00000000e+00, -9.00000000e-01, -8.00000000e-01, -7.00000000e-01,
#        -6.00000000e-01, -5.00000000e-01, -4.00000000e-01, -3.00000000e-01,
#        -2.00000000e-01, -1.00000000e-01, -1.77635684e-14,  1.00000000e-01,
#         2.00000000e-01,  3.00000000e-01,  4.00000000e-01,  5.00000000e-01,
#         6.00000000e-01,  7.00000000e-01,  8.00000000e-01,  9.00000000e-01,
#         1.00000000e+00,  1.10000000e+00,  1.20000000e+00,  1.30000000e+00,
#         1.40000000e+00,  1.50000000e+00,  1.60000000e+00,  1.70000000e+00,
#         1.80000000e+00,  1.90000000e+00,  2.00000000e+00,  2.10000000e+00,
#         2.20000000e+00,  2.30000000e+00,  2.40000000e+00,  2.50000000e+00,
#         2.60000000e+00,  2.70000000e+00,  2.80000000e+00,  2.90000000e+00,
#         3.00000000e+00,  3.10000000e+00,  3.20000000e+00,  3.30000000e+00,
#         3.40000000e+00,  3.50000000e+00,  3.60000000e+00,  3.70000000e+00,
#         3.80000000e+00,  3.90000000e+00,  4.00000000e+00,  4.10000000e+00,
#         4.20000000e+00,  4.30000000e+00,  4.40000000e+00,  4.50000000e+00,
#         4.60000000e+00,  4.70000000e+00,  4.80000000e+00,  4.90000000e+00])

# %%
y1 = x**2 + 3
y1
# Out:
# array([28.  , 27.01, 26.04, 25.09, 24.16, 23.25, 22.36, 21.49, 20.64,
#        19.81, 19.  , 18.21, 17.44, 16.69, 15.96, 15.25, 14.56, 13.89,
#        13.24, 12.61, 12.  , 11.41, 10.84, 10.29,  9.76,  9.25,  8.76,
#         8.29,  7.84,  7.41,  7.  ,  6.61,  6.24,  5.89,  5.56,  5.25,
#         4.96,  4.69,  4.44,  4.21,  4.  ,  3.81,  3.64,  3.49,  3.36,
#         3.25,  3.16,  3.09,  3.04,  3.01,  3.  ,  3.01,  3.04,  3.09,
#         3.16,  3.25,  3.36,  3.49,  3.64,  3.81,  4.  ,  4.21,  4.44,
#         4.69,  4.96,  5.25,  5.56,  5.89,  6.24,  6.61,  7.  ,  7.41,
#         7.84,  8.29,  8.76,  9.25,  9.76, 10.29, 10.84, 11.41, 12.  ,
#        12.61, 13.24, 13.89, 14.56, 15.25, 15.96, 16.69, 17.44, 18.21,
#        19.  , 19.81, 20.64, 21.49, 22.36, 23.25, 24.16, 25.09, 26.04,
#        27.01])

# %%
# figure 크기 조정하기
plt.figure(figsize=(5,5))
plt.title('그래프를 그려보자', fontsize=15)
plt.scatter(x, y1)
plt.show()

# %% [markdown]
# ### 4-2. 그래프 여러 개 그리기

# %% [markdown]
# 1. Figure 객체와 axes를 직접 생성 후 생성된 axes에 대한 plot 멤버를 직접 호출하는 방법
#     ```
# fig = plt.figure()
# axs = fig.subplots(1,2)
# ```
# 2. pyplot.subplots 으로 Figure와 axes를 생성하는 방법
#     ```
# fig, axs = plt.subplots(1,2)
# ```
# 3. Figure 객체 생성 후, axes 추가하는 방법
#     ```
# fig = plt.figure()
# ax1 = fig.add_subplot(1, 2, 1)
# ax2 = fig.add_subplot(1, 2, 2) # 1행 2열에서 두번쨰 데이터
# ```

# %% [markdown]
# - $-5 < x < 5$ , (x의 간격은 0.1)
# - $y_1=x^2+3$
# - $y_2=x+2$

# %%
y2 = x+2
y2
# Out:
# array([-3.0000000e+00, -2.9000000e+00, -2.8000000e+00, -2.7000000e+00,
#        -2.6000000e+00, -2.5000000e+00, -2.4000000e+00, -2.3000000e+00,
#        -2.2000000e+00, -2.1000000e+00, -2.0000000e+00, -1.9000000e+00,
#        -1.8000000e+00, -1.7000000e+00, -1.6000000e+00, -1.5000000e+00,
#        -1.4000000e+00, -1.3000000e+00, -1.2000000e+00, -1.1000000e+00,
#        -1.0000000e+00, -9.0000000e-01, -8.0000000e-01, -7.0000000e-01,
#        -6.0000000e-01, -5.0000000e-01, -4.0000000e-01, -3.0000000e-01,
#        -2.0000000e-01, -1.0000000e-01, -1.0658141e-14,  1.0000000e-01,
#         2.0000000e-01,  3.0000000e-01,  4.0000000e-01,  5.0000000e-01,
#         6.0000000e-01,  7.0000000e-01,  8.0000000e-01,  9.0000000e-01,
#         1.0000000e+00,  1.1000000e+00,  1.2000000e+00,  1.3000000e+00,
#         1.4000000e+00,  1.5000000e+00,  1.6000000e+00,  1.7000000e+00,
#         1.8000000e+00,  1.9000000e+00,  2.0000000e+00,  2.1000000e+00,
#         2.2000000e+00,  2.3000000e+00,  2.4000000e+00,  2.5000000e+00,
#         2.6000000e+00,  2.7000000e+00,  2.8000000e+00,  2.9000000e+00,
#         3.0000000e+00,  3.1000000e+00,  3.2000000e+00,  3.3000000e+00,
#         3.4000000e+00,  3.5000000e+00,  3.6000000e+00,  3.7000000e+00,
#         3.8000000e+00,  3.9000000e+00,  4.0000000e+00,  4.1000000e+00,
#         4.2000000e+00,  4.3000000e+00,  4.4000000e+00,  4.5000000e+00,
#         4.6000000e+00,  4.7000000e+00,  4.8000000e+00,  4.9000000e+00,
#         5.0000000e+00,  5.1000000e+00,  5.2000000e+00,  5.3000000e+00,
#         5.4000000e+00,  5.5000000e+00,  5.6000000e+00,  5.7000000e+00,
#         5.8000000e+00,  5.9000000e+00,  6.0000000e+00,  6.1000000e+00,
#         6.2000000e+00,  6.3000000e+00,  6.4000000e+00,  6.5000000e+00,
#         6.6000000e+00,  6.7000000e+00,  6.8000000e+00,  6.9000000e+00])

# %%
fig, axs = plt.subplots(2,3)
axs[0, 0].plot(x, y2)
axs[0, 1].plot(x, y1)
axs[0, 2].plot(x, y2)
plt.show() # 0,0 0,1 0,2 1,0 1,1 1,2

# %%
# 사이즈 조절 figsize=(,)
fig, axs = plt.subplots(1,2, figsize=(10,5))
axs[0].plot(x, y2)
axs[1].plot(x, y1)

plt.show()

# %%
fig = plt.figure(figsize=(10,5))
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

ax1.plot(x, y2)
ax2.plot(x, y1)

plt.show()

# %%
# [참고] pyplot API 방식. 위 그래프와 같다

# 사이즈 설정
plt.rcParams["figure.figsize"] = (10,5)

plt.subplot(1,2,1)
plt.plot(x, y2)

plt.subplot(1,2,2)
plt.plot(x, y1)

plt.show()

# %%
plt.rcParams["figure.figsize"] = (6, 6)
fig, axs = plt.subplots()
axs.plot([1,2,3,4], [100,200,300,400])

plt.show()

# %% [markdown]
# - 세로로 화면을 분할하여 그래프를 그려보기

# %%
fig=plt.figure()
ax1=fig.add_subplot(2,1,1)
ax2=fig.add_subplot(2,1,2)

ax1.plot(y1)
ax2.plot(y2)

plt.show()

# %% [markdown]
# - 그래프에 가로선 그어보기
# - x = range(0, 10)
# - $y_1=v^2$ &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;($\rightarrow$ y1 = [v*v for v in x] )
# - $y_2=log(v)$ &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;($\rightarrow$ y2 = [np.log(v) for v in x] )

# %%
x = np.arange(0, 10, 0.1)
y1 = x ** 2
y2 = np.log(x)

fig = plt.figure()
axs = fig.subplots(1,2)
axs[0].plot(x, y1)
axs[1].plot(x, y2)
axs[0].axvline(x=0, color = 'k') # draw x=0 axes (Y축), axv(vertical line)
axs[0].axhline(y=80, color = 'r') # draw y=0 axes (X축), axh(horizontal line)
axs[1].axvline(x=0, color = 'k') # draw x=0 axes (Y축)
axs[1].axhline(y=0, color = 'r') # draw y=0 axes (X축)
plt.show()

# %% [markdown]
# - 2행 1열의 axes에 $sin(x)$ 그래프와 $cos(x)$ 그래프 그려보기
#     - x축을 표시하시오
#     - x의 범위는 0부터 2*pi까지, 0.1 간격으로
#     - sin_y=np.sin(x)
#     - cos_y=np.cos(x)

# %%
fig = plt.figure(figsize=(9,3))
axs = fig.subplots(2, 1)

x=np.arange(0, 2*np.pi, 0.1)
sin_y=np.sin(x)
cos_y=np.cos(x)

axs[0].plot(x,sin_y, 'b--') # b : blue, r : red, k : black
axs[0].axhline(y=0, color='k')

axs[1].plot(x,cos_y)
axs[1].axhline(y=0, color = 'r')

plt.show()

# %% [markdown]
# ### 3-3. Axis

# %% [markdown]
# <center><img src='https://raw.githubusercontent.com/aidalabs/Lectures/master/LectureFiles/images/Py004_Matplotlib_003.png' width="" height ="" /></center><br /><br />

# %% [markdown]
# #### 3.3.1 xlim, ylim
# ```
# ax.set_xlim([0, 10])
# ax.set_ylim([0, 20])
# ```

# %%
# x값은 0~10, 1단위로
# y값은 x+10

x = np.arange(10)
y = x+10 # yticks에는 [0,1,2,...9,10,11,12...,19]

fig, axs = plt.subplots()
axs.plot(x, y)
axs.set_xlim([0, 10])
axs.set_ylim([0, 20])

plt.show()

# %%
# [참고] pyplot API 방식. 위 그래프와 같다

plt.plot(x,y)
#plt.axis([0, 10, 0, 20])
plt.xlim([0, 10])
plt.ylim([0, 20])
plt.show()

# %% [markdown]
# #### 3.3.2 ticks

# %%
# x값은 0~10, 1단위로
# y값은 x+10

x = np.arange(10)
y = x+10 # yticks에는 [0,1,2,...9,10,11,12...,19]

fig, axs = plt.subplots()
axs.plot(x, y)
axs.set_xlim([0, 10])
axs.set_ylim([0, 20])

axs.set_xticks([0,2,4,6,8,10])
axs.set_yticks(range(0,20))

axs.set_xticklabels(['A','B','C','D','E','F'])

plt.show()

# %% [markdown]
# ### 3-4. Legend

# %%
x = np.arange(-np.pi, np.pi, 0.02)
y1 = np.sin(x)
y2 = np.cos(x)

fig, ax = plt.subplots()

ax.plot(x, y1, label = 'sin')
ax.plot(x, y2, label = 'cos')

ax.legend(loc='center')
#ax.legend([line1, line2, line3], ['label1', 'label2', 'label3'])

plt.show()

# %%
# [참고] pyplot API 방식. 위 그래프와 같다

x = np.arange(-np.pi, np.pi, 0.02)
y1 = np.sin(x)
y2 = np.cos(x)

plt.plot(x, y1, label = 'sin')
plt.plot(x, y2, label = 'cos')

plt.legend(loc='upper left')

plt.show()

# %% [markdown]
# - 범례(Legend) 위치 표시 코드
# <center><img src='https://raw.githubusercontent.com/aidalabs/Lectures/master/LectureFiles/images/Py004_Matplotlib_004.png' width="" height ="" /></center><br /><br />

# %% [markdown]
# ### 3-5. Text

# %% [markdown]
# #### 3.5.1 fig와 axes의 title

# %%
x = np.arange(-np.pi, np.pi, 0.02)
y1 = np.sin(x)
y2 = np.cos(x)

fig,axs = plt.subplots(1,2)

axs[0].plot(x, y1)
axs[1].plot(x, y2)

axs[0].set_title('sin')
axs[1].set_title('cos')
fig.suptitle('삼각함수')

plt.show()

# %% [markdown]
# #### 3.5.2 x, y label

# %%
# [참고] pyplot API 방식. label 달기

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %%
x = np.arange(-np.pi, np.pi, 0.02)
y1 = np.sin(x)
y2 = np.cos(x)

fig,axs = plt.subplots(1,2)
axs[0].plot(x, y1)
axs[1].plot(x, y2)

axs[0].set_title('sin')
axs[1].set_title('cos')
fig.suptitle('삼각함수')

axs[0].set_xlabel('x값', ha='left', va = 'top')
axs[1].set_xlabel('x값')

axs[0].set_ylabel('sin값')
axs[1].set_ylabel('cos값')

plt.show()

# %%
# label 위치 바꾸기

import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots()
ax.set_xticks(np.arange(0,6,1))

label = ax.set_xlabel('Xlabel', horizontalalignment='left', fontsize = 20)
#label = ax.set_xlabel('Xlabel', ha='right', fontsize = 20)

ax.xaxis.set_label_coords(1,1) # 0~1
#ax.xaxis.set_label_position('bottom')

plt.show()

# %% [markdown]
# #### 3.5.3 text

# %%
x = np.arange(8)
y = x**2

fig, ax = plt.subplots()
ax.plot(x, y, 'ro') # 색깔 r: red, o: 동그라미

for x_, y_ in zip(x, y):
    t = '(%d, %d)'%(int(x_), int(y_))
    ax.text(x_+0.1, y_+0.1,t) # 위치 조정 후 text 넣기

# %% [markdown]
# #### 3.5.4 annotate

# %%
x = np.arange(-1, 3, 0.01)
y = -x**4+4*x**3-4*x**2

fig, ax = plt.subplots()
ax.plot(x, y, lw=2) # lw==linewidth
#https://datascienceschool.net/01%20python/05.01%20%EC%8B%9C%EA%B0%81%ED%99%94%20%ED%8C%A8%ED%82%A4%EC%A7%80%20%EB%A7%B7%ED%94%8C%EB%A1%AF%EB%A6%AC%EB%B8%8C%20%EC%86%8C%EA%B0%9C.html
ax.annotate('local mininmum', xy=(1, -1), xytext=(0, -3.5),
            arrowprops=dict(facecolor='red'))
ax.set_ylim(-10,2)
plt.show()

# %% [markdown]
# ### 3-6.color
#
# - 참고: https://matplotlib.org/stable/api/colors_api.html

# %%
x = np.arange(-np.pi, np.pi, 0.02)
y1 = np.sin(x)
y2 = np.cos(x)

fig, ax = plt.subplots()

ax.plot(x, y1, label = 'sin', color= (0.1, 0.3, 0.5)) # RGB
ax.plot(x, y2, label = 'cos', color='m')
# one of {'b', 'g', 'r', 'c', 'm', 'y', 'k', 'w'} blue green red cyan magenta yello black white

ax.legend(loc='upper right')

plt.show()

# %% [markdown]
# ### 3-7. facecolor
#
# - 참고: https://matplotlib.org/stable/api/colors_api.html

# %%
#ax.set_facecolor()
x = np.arange(-np.pi, np.pi, 0.02)
y1 = np.sin(x)
y2 = np.cos(x)


fig,axs = plt.subplots(1,2)

axs[0].plot(x, y1)
axs[1].plot(x, y2)
axs[0].set_title('sin')
axs[1].set_title('cos')
fig.suptitle('삼각함수')

axs[0].set_xlabel('x값', ha='left', va = 'top')
axs[1].set_xlabel('x값')

axs[0].set_ylabel('sin값')
axs[1].set_ylabel('cos값')

axs[0].set_facecolor('pink')
axs[1].set_facecolor('skyblue')
fig.set_facecolor("g")

plt.show()

# %% [markdown]
# ### 3-8. grid

# %%
x = np.arange(-np.pi, np.pi, 0.02)
y1 = np.sin(x)
y2 = np.cos(x)

fig, ax = plt.subplots()

ax.plot(x, y1, label = 'sin')
ax.plot(x, y2, label = 'cos')

ax.legend(loc='upper right')

ax.grid(color='r', linestyle='--', linewidth=0.5)
plt.show()

# %% [markdown]
# ## **5.여러가지 그래프**
#
# - 참고: https://matplotlib.org/stable/tutorials/introductory/sample_plots.html

# %% [markdown]
# ### 5-1.Line Plot
#
# - marker 참고: https://matplotlib.org/stable/api/markers_api.html
# - line style 참고: https://matplotlib.org/stable/gallery/lines_bars_and_markers/linestyles.html

# %%
x = np.arange(-5, 5, 0.5)
y1 = x
y2 = x+2
y3 = x+4
y4 = x+6

fig, ax = plt.subplots()
ax.plot(x, y1)
ax.plot(x, y2, marker='s',color='g',linestyle='dotted')
ax.plot(x, y3, color='k')
ax.plot(x, y4, linestyle='dotted')
plt.show()

# %% [markdown]
# ###  5-2.Bar Plot

# %%
fruits = {'사과': 21, '바나나': 15, '배': 5, '키위': 20}
names = list(fruits.keys())
values = list(fruits.values())

fig, ax = plt.subplots()
ax.bar(names, values)
plt.show()

# %%
fruits = {'사과': 21, '바나나': 15, '배': 5, '키위': 20}
names = list(fruits.keys())
values = list(fruits.values())

fig, ax = plt.subplots()
ax.barh(names, values)
plt.show()

# %%
labels = ['정직한후보', '작은아씨들', '클로젯', '조조래빗']
user = [9.2, 9.4, 8.6, 9.16]
critic = [5.4, 8, 5.5, 7.17]

fig, ax = plt.subplots()
ax.bar(labels, user, color='g')
ax.bar(labels, critic, color='r')

plt.show()

# %%
labels = ['정직한후보', '작은아씨들', '클로젯', '조조래빗']
user = [9.2, 9.4, 8.6, 9.16]
critic = [5.4, 8, 5.5, 7.17]

fig, ax = plt.subplots()

x = np.arange(len(labels))  # the label locations
width=0.35
ax1=ax.bar(x-width/2, user, width, color='skyblue')
ax2=ax.bar(x+width/2, critic, width, color='k')

plt.show()

# %%
labels = ['정직한후보', '작은아씨들', '클로젯', '조조래빗']
user = [9.2, 9.4, 8.6, 9.16]
critic = [5.4, 8, 5.5, 7.17]

fig, ax = plt.subplots()

x = np.arange(len(labels))  # the label locations
width=0.35

ax.bar(x-width/2, user, width, color='skyblue')
ax.bar(x+width/2, critic, width, color='r')

# ax.bar(x-width/2,user, color='g', width = width, label='관객평점')
# ax.bar(x+width/2, critic, color='r', width = width, label='전문가평점')
ax.legend(['관객평점', '전문가평점'], loc='upper right')

ax.set_xticks(x)
ax.set_xticklabels(labels)

ax.set_ylim([0, 12])

ax.set_title('오래된 영화 평점', fontsize=20, color = 'b')

plt.show()

# %% [markdown]
# ### 5-3.Histogram

# %%
data = np.random.rand(10000) # [0, 1) 범위에서 균일한 분포를 갖는 난수 10000개 생성

fig, ax = plt.subplots()
ax.hist(data, bins = 10, facecolor='r')
ax.grid(True)

plt.show()

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(1000)

fig, ax = plt.subplots()

# the histogram of the data
# histtype{'bar', 'barstacked', 'step', 'stepfilled'}, default: 'bar'
ax.hist(x, 10,  density=True, facecolor='g', histtype='barstacked')
plt.show()

# %% [markdown]
# ### 5-4.Scatter Plot

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
area =(20 * np.random.rand(N))**2

fig, ax = plt.subplots()
ax.scatter(x, y, s=area, marker='o', c=area)
# s: size
# c: color

plt.show()

# %% [markdown]
# ### 5-5.heatmap

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

vegetables = ["cucumber", "tomato", "lettuce", "asparagus",
              "potato", "wheat", "barley"]
farmers = ["Farmer Joe", "Upland Bros.", "Smith Gardening",
           "Agrifun", "Organiculture", "BioGoods Ltd.", "Cornylee Corp."]

harvest = np.array([[0.8, 2.4, 2.5, 3.9, 0.0, 4.0, 0.0],
                    [2.4, 0.0, 4.0, 1.0, 2.7, 0.0, 0.0],
                    [1.1, 2.4, 0.8, 4.3, 1.9, 4.4, 0.0],
                    [0.6, 0.0, 0.3, 0.0, 3.1, 0.0, 0.0],
                    [0.7, 1.7, 0.6, 2.6, 2.2, 6.2, 0.0],
                    [1.3, 1.2, 0.0, 0.0, 0.0, 3.2, 5.1],
                    [0.1, 2.0, 0.0, 1.4, 0.0, 1.9, 6.3]])

fig, ax = plt.subplots()
im = ax.imshow(harvest)

# We want to show all ticks...
ax.set_xticks(np.arange(len(farmers)))
ax.set_yticks(np.arange(len(vegetables)))
# ... and label them with the respective list entries
ax.set_xticklabels(farmers)
ax.set_yticklabels(vegetables)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(vegetables)):
    for j in range(len(farmers)):
        text = ax.text(j, i, harvest[i, j],
                       ha="center", va="center", color="w")

ax.set_title("Harvest of local farmers (in tons/year)")
fig.tight_layout()
plt.show()

# %%
harvest = np.array([[0.8, 2.4, 2.5, 3.9, 0.0, 4.0, 0.0],
                    [2.4, 0.0, 4.0, 1.0, 2.7, 0.0, 0.0],
                    [1.1, 2.4, 0.8, 4.3, 1.9, 4.4, 0.0],
                    [0.6, 0.0, 0.3, 0.0, 3.1, 0.0, 0.0],
                    [0.7, 1.7, 0.6, 2.6, 2.2, 6.2, 0.0],
                    [1.3, 1.2, 0.0, 0.0, 0.0, 3.2, 5.1],
                    [0.1, 2.0, 0.0, 1.4, 0.0, 1.9, 6.3]])

fig, ax = plt.subplots()
ax.imshow(harvest)
plt.show()

# %% [markdown]
# ## **6.저장 (savefig)**
#
# - 참고: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.savefig.html?highlight=savefig

# %%
savefile_path = './scatter.jpg'
print(savefile_path)
fig.savefig(savefile_path)
# Out:
# ./scatter.jpg

# %%
import matplotlib.image as mpimg

img = mpimg.imread(savefile_path)
print(type(img))
print(img)
plt.imshow(img)
# Out:
# <class 'numpy.ndarray'>
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
import PIL.Image as pilimg

img = pilimg.open(savefile_path)
print(type(img))
print(img)
img
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x600 at 0x7F60195DF910>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x600>

# %% [markdown]
# ## **4. 실제 데이터로 그려보기**

# %% [markdown]
# - csv 파일을 읽어서 그 데이터를 그래프로 그려보자

# %%
import pandas as pd

# %%
# cctv = pd.read_csv('./CCTV_20190920.csv', encoding='cp949')
cctv = pd.read_csv('https://raw.githubusercontent.com/aidalabs/Lectures/master/LectureFiles/dataset/Sejong_CCTV_20190920.csv', encoding='cp949')
cctv.head()
# Out:
#      관리기관명              소재지도로명주소                  소재지지번주소 설치목적구분  카메라대수  \
# 0  세종특별자치시                   NaN     세종특별자치시 조치원읍 신흥리 447    다목적      4
# 1  세종특별자치시                   NaN   세종특별자치시 조치원읍 신흥리 11-27    다목적      3
# 2  세종특별자치시                   NaN      세종특별자치시 조치원읍 남리 239    다목적      2
# 3  세종특별자치시  세종특별자치시 조치원읍 침산3길 32   세종특별자치시 조치원읍 침산리 87-24    다목적      4
# 4  세종특별자치시                   NaN  세종특별자치시 조치원읍 침산리 144-12    다목적      3
#
#    카메라화소수                                             촬영방면정보  보관일수  설치년월  \
# 0     200                   1)푸르지오아파트 2)농정원 3)신동아아파트 4)세종경찰서    30   NaN
# 1     200                                 1)신흥빌라 2)충렬탑 3)대동초    30   NaN
# 2     200                                 1)공영주차장 2)청주방향지하차도    30   NaN
# 3     200  1)돈까스클럽 방향, 2) 하사관주택방향, 3) 마을안길 서쪽방향, 4) 마을안길 ...    30   NaN
# 4     200                           1)고려대방면 2)신흥사거리방면 3)마을방면    30   NaN
#
#        관리기관전화번호         위도          경도     데이터기준일자
# 0  044-300-2454  36.592523  127.293542  2019-09-20
# 1  044-300-2454  36.597449  127.293396  2019-09-20
# 2  044-300-2454  36.598000  127.301910  2019-09-20
# 3  044-300-2454  36.600946  127.291716  2019-09-20
# 4  044-300-2454  36.601083  127.294851  2019-09-20

# %%
cctv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 965 entries, 0 to 964
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   관리기관명     965 non-null    object
#  1   소재지도로명주소  389 non-null    object
#  2   소재지지번주소   791 non-null    object
#  3   설치목적구분    965 non-null    object
#  4   카메라대수     965 non-null    int64
#  5   카메라화소수    965 non-null    int64
#  6   촬영방면정보    882 non-null    object
#  7   보관일수      965 non-null    int64
#  8   설치년월      0 non-null      float64
#  9   관리기관전화번호  965 non-null    object
#  10  위도        965 non-null    float64
#  11  경도        965 non-null    float64
#  12  데이터기준일자   965 non-null    object
# dtypes: float64(3), int64(3), object(7)
# memory usage: 98.1+ KB

# %%
cctv.describe()
# Out:
#             카메라대수      카메라화소수   보관일수  설치년월          위도          경도
# count  965.000000  965.000000  965.0   0.0  965.000000  965.000000
# mean     1.843523  170.022798   30.0   NaN   36.530123  127.269428
# std      0.937559   55.130941    0.0   NaN    0.060557    0.039567
# min      1.000000   40.000000   30.0   NaN   36.407482  127.142201
# 25%      1.000000  130.000000   30.0   NaN   36.488390  127.248586
# 50%      2.000000  200.000000   30.0   NaN   36.508438  127.267834
# 75%      3.000000  200.000000   30.0   NaN   36.562659  127.292945
# max      6.000000  300.000000   30.0   NaN   36.731322  127.402522

# %%
# x축은 카메라 화소수, y축은 카메라 대수
# 카메라화소수가 얼마얼마 있는지 unique한 값을 찾아서 오름차순으로 정렬 ==> x

# %%
cctv['카메라화소수'].unique()
# Out:
# array([200,  41, 130,  40, 300])

# %%
cctv['카메라화소수'].value_counts()
# Out:
# 200    707
# 130    133
# 41     122
# 40       2
# 300      1
# Name: 카메라화소수, dtype: int64

# %%
data = cctv['카메라화소수'].value_counts().sort_index()
data
# Out:
# 40       2
# 41     122
# 130    133
# 200    707
# 300      1
# Name: 카메라화소수, dtype: int64

# %%
x = data.index
x
# Out:
# Int64Index([40, 41, 130, 200, 300], dtype='int64')

# %%
y = data.values
y
# Out:
# array([  2, 122, 133, 707,   1])

# %%
fig, ax = plt.subplots()
ax.plot(x, y)
plt.show()

# %% [markdown]
# - x는 0부터 400까지, y는 0부터 1000까지로 그래프 범위를 지정해보자

# %%
fig, axs = plt.subplots()
axs.plot(data.index, data.values)

axs.set_xlim([0, 400])
axs.set_ylim([0, 1000])

plt.show()

# %% [markdown]
# - 화소 수를 100만 단위로 Tick을 지정해보자

# %%
fig, axs = plt.subplots()
axs.plot(data.index, data.values)

axs.set_xlim([0,400])
axs.set_ylim([0,1000])
axs.set_xticks([0,100,200,300,400])
axs.set_xticklabels(['0화소','100만화소','200만화소','300만화소','400만화소'])

plt.show()

# %% [markdown]
# - 범례 위치를 옮겨보자

# %%
fig, axs = plt.subplots()
axs.plot(data.index, data.values, label='카메라 화소')

axs.set_xlim([0, 400])
axs.set_ylim([0, 1000])

axs.set_xticks([0,100,200,300,400])
axs.set_xticklabels(['0화소','1백만화소','2백만화소','3백만화소','4백만화소'])

axs.legend(loc='upper right')

plt.show()

# %% [markdown]
# - 그래프에 figure와 axes의 Title을 달아보자

# %%
fig, axs = plt.subplots()

axs.set_title('카메라화소')
fig.suptitle('화소')


axs.plot(data.index, data.values, label='카메라 화소')
axs.set_xlim([0, 400])
axs.set_ylim([0, 1000])
axs.set_xticks([0,100,200,300,400])
axs.set_xticklabels(['0화소','1백만화소','2백만화소','3백만화소','4백만화소'])
axs.legend(loc='upper right')
plt.show()

# %% [markdown]
# - CCTV 그래프에 x축, y축의 label을 달아보자.
#   - x축: CCTV 화소수
#   - y축: CCTV 대수

# %%
fig, axs = plt.subplots()
axs.plot(data.index, data.values, label='카메라 화소')

# title
fig.suptitle('화소')
axs.set_title('카메라화소')

# xlim, ylim
axs.set_xlim([0, 400])
axs.set_ylim([0, 1000])

# xticks, xticklabels
axs.set_xticks([0,100,200,300,400])
axs.set_xticklabels(['0화소','1백만화소','2백만화소','3백만화소','4백만화소'])

# legend
axs.legend(loc='upper right')

# xlabel, ylabel
axs.set_xlabel('CCTV 화소수')
axs.set_ylabel('CCTV 대수')

plt.show()

# %% [markdown]
# - 그래프에 text를 달아보자

# %%
fig, ax = plt.subplots()
ax.plot(data.index, data.values, label='카메라 화소')

ax.set_xlim([0, 400])
ax.set_ylim([0, 1000])

ax.set_xticks([0,100,200,300,400])
ax.set_xticklabels(['0화소','1백만화소','2백만화소','3백만화소','4백만화소'])

ax.legend(loc='upper right')

ax.set_xlabel('CCTV 화소수')
ax.set_ylabel('CCTV 대수')

for x_, y_ in zip(data.index, data.values):
  ax.text(x_+1, y_, '%d대'%(int(y_)))

plt.show()

# %%
fig, axs = plt.subplots()

axs.plot(data.index, data.values, label='카메라 화소')

axs.set_xlim([0, 400])
axs.set_ylim([0, 1000])

axs.set_xticks([0,100,200,300,400])
axs.set_xticklabels(['0화소','1백만화소','2백만화소','3백만화소','4백만화소'])

axs.legend(loc='upper right')

axs.set_xlabel('CCTV 화소수')
axs.set_ylabel('CCTV 대수')

for x_, y_ in zip(data.index, data.values):
    axs.text(x_+1, y_,'%d, %d' % (int(x_), int(y_)))

plt.show()

# %% [markdown]
# - 그래프에 화살표를 달아보자. 그 외에도 다른 annotation이 있는지 더 찾아보고 달아보자

# %%
# 707 위치에 '가장 많음'이라고 달아보자

fig, ax = plt.subplots()
ax.plot(data.index, data.values, label='카메라 화소')

ax.set_xlim([0, 400])
ax.set_ylim([0, 1000])

ax.set_xticks([0,100,200,300,400])
ax.set_xticklabels(['0화소','1백만화소','2백만화소','3백만화소','4백만화소'])

ax.legend(loc='upper right')

ax.set_xlabel('CCTV 화소수')
ax.set_ylabel('CCTV 대수')

for x_, y_ in zip(data.index, data.values):
  ax.text(x_+1, y_, '%d대'%(int(y_)))

ax.annotate('가장 많음', xy=(200,707), xytext=(100,700),arrowprops=dict(facecolor='red'))

plt.show()

# %% [markdown]
# - 그래프의 색상을 바꿔보자

# %%
fig, ax = plt.subplots()
ax.plot(data.index, data.values, label='카메라 화소', color='r')

ax.set_xlim([0, 400])
ax.set_ylim([0, 1000])

ax.set_xticks([0,100,200,300,400])
ax.set_xticklabels(['0화소','1백만화소','2백만화소','3백만화소','4백만화소'])

ax.legend(loc='upper right')

ax.set_xlabel('CCTV 화소수')
ax.set_ylabel('CCTV 대수')

for x_, y_ in zip(data.index, data.values):
  ax.text(x_+1, y_+20, '%d대'%int(y_))

ax.annotate('가장 많음', xy=(200,707), xytext=(100,700),arrowprops=dict(facecolor='blue'))

plt.show()

# %% [markdown]
# - 그래프의 배경색상을 바꿔보자

# %%
fig, ax = plt.subplots()

ax.plot(data.index, data.values, label='카메라 화소', color='r')

ax.set_xlim([0, 400])
ax.set_ylim([0, 1000])

ax.set_xticks([0,100,200,300,400])
ax.set_xticklabels(['0화소','1백만화소','2백만화소','3백만화소','4백만화소'])

ax.legend(loc='upper right')

ax.set_xlabel('CCTV 화소수')
ax.set_ylabel('CCTV 대수')

for x_, y_ in zip(data.index, data.values):
  ax.text(x_+1, y_+20, '%d대'%int(y_))

ax.annotate('가장 많음', xy=(200,707), xytext=(100,700),arrowprops=dict(facecolor='blue'))

ax.set_facecolor('c')
fig.set_facecolor('y')

plt.show()

# %% [markdown]
# - 그래프에 그리드(grid)를 넣어보자.

# %%
fig, ax = plt.subplots()
ax.plot(data.index, data.values, label='카메라 화소', color='r')
ax.set_xlim([0, 400])
ax.set_ylim([0, 1000])
ax.set_xticks([0,100,200,300,400])
ax.set_xticklabels(['0화소','1백만화소','2백만화소','3백만화소','4백만화소'])
ax.legend(loc='upper right')
ax.set_xlabel('CCTV 화소수')
ax.set_ylabel('CCTV 대수')
for x_, y_ in zip(data.index, data.values):
  ax.text(x_+1, y_+20, '%d대'%int(y_))
ax.annotate('가장 많음', xy=(200,707), xytext=(100,700),arrowprops=dict(facecolor='blue'))
ax.set_facecolor('cyan')
fig.set_facecolor('pink')
ax.grid(color='r', linestyle='--', linewidth=1)
plt.show()

# %% [markdown]
# ## **7. 지도에 표시해보기**

# %%
import folium

# %%
mymap = folium.Map(location=[36.6208541,127.2849716], zoom_start=13) # 위도, 경도, 축척
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_336c146aef34f4d25103ab6c0e3e0f55 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_336c146aef34f4d25103ab6c0e3e0f55&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_336c146aef34f4d25103ab6c0e3e0f55 = L.map(
#                 &quot;map_336c146aef34f4d25103ab6c0e3e0f55&quot;,
#                 {
#                     center: [36.6208541, 127.2849716],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_88e5e71373f97ad21fed339d6d53946b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_336c146aef34f4d25103ab6c0e3e0f55);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Marker([36.6208541,127.2849716], popup="Hongik Uni").add_to(mymap)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_336c146aef34f4d25103ab6c0e3e0f55 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_336c146aef34f4d25103ab6c0e3e0f55&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_336c146aef34f4d25103ab6c0e3e0f55 = L.map(
#                 &quot;map_336c146aef34f4d25103ab6c0e3e0f55&quot;,
#                 {
#                     center: [36.6208541, 127.2849716],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_88e5e71373f97ad21fed339d6d53946b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_336c146aef34f4d25103ab6c0e3e0f55);
#
#
#             var marker_fc022668b5423b9370dcd388faaa68ba = L.marker(
#                 [36.6208541, 127.2849716],
#                 {}
#             ).addTo(map_336c146aef34f4d25103ab6c0e3e0f55);
#
#
#         var popup_bad62dc5036317aceadfa1fcab6908b6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7375a3b608a81431c337c6051acd8f97 = $(`&lt;div id=&quot;html_7375a3b608a81431c337c6051acd8f97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hongik Uni&lt;/div&gt;`)[0];
#                 popup_bad62dc5036317aceadfa1fcab6908b6.setContent(html_7375a3b608a81431c337c6051acd8f97);
#
#
#
#         marker_fc022668b5423b9370dcd388faaa68ba.bindPopup(popup_bad62dc5036317aceadfa1fcab6908b6)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
cctv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 965 entries, 0 to 964
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   관리기관명     965 non-null    object
#  1   소재지도로명주소  389 non-null    object
#  2   소재지지번주소   791 non-null    object
#  3   설치목적구분    965 non-null    object
#  4   카메라대수     965 non-null    int64
#  5   카메라화소수    965 non-null    int64
#  6   촬영방면정보    882 non-null    object
#  7   보관일수      965 non-null    int64
#  8   설치년월      0 non-null      float64
#  9   관리기관전화번호  965 non-null    object
#  10  위도        965 non-null    float64
#  11  경도        965 non-null    float64
#  12  데이터기준일자   965 non-null    object
# dtypes: float64(3), int64(3), object(7)
# memory usage: 98.1+ KB

# %%
cctv.head()
# Out:
#      관리기관명              소재지도로명주소                  소재지지번주소 설치목적구분  카메라대수  \
# 0  세종특별자치시                   NaN     세종특별자치시 조치원읍 신흥리 447    다목적      4
# 1  세종특별자치시                   NaN   세종특별자치시 조치원읍 신흥리 11-27    다목적      3
# 2  세종특별자치시                   NaN      세종특별자치시 조치원읍 남리 239    다목적      2
# 3  세종특별자치시  세종특별자치시 조치원읍 침산3길 32   세종특별자치시 조치원읍 침산리 87-24    다목적      4
# 4  세종특별자치시                   NaN  세종특별자치시 조치원읍 침산리 144-12    다목적      3
#
#    카메라화소수                                             촬영방면정보  보관일수  설치년월  \
# 0     200                   1)푸르지오아파트 2)농정원 3)신동아아파트 4)세종경찰서    30   NaN
# 1     200                                 1)신흥빌라 2)충렬탑 3)대동초    30   NaN
# 2     200                                 1)공영주차장 2)청주방향지하차도    30   NaN
# 3     200  1)돈까스클럽 방향, 2) 하사관주택방향, 3) 마을안길 서쪽방향, 4) 마을안길 ...    30   NaN
# 4     200                           1)고려대방면 2)신흥사거리방면 3)마을방면    30   NaN
#
#        관리기관전화번호         위도          경도     데이터기준일자
# 0  044-300-2454  36.592523  127.293542  2019-09-20
# 1  044-300-2454  36.597449  127.293396  2019-09-20
# 2  044-300-2454  36.598000  127.301910  2019-09-20
# 3  044-300-2454  36.600946  127.291716  2019-09-20
# 4  044-300-2454  36.601083  127.294851  2019-09-20

# %%
cctv[['위도','경도']]
# Out:
#             위도          경도
# 0    36.592523  127.293542
# 1    36.597449  127.293396
# 2    36.598000  127.301910
# 3    36.600946  127.291716
# 4    36.601083  127.294851
# ..         ...         ...
# 960  36.508301  127.268698
# 961  36.487283  127.256484
# 962  36.483835  127.258719
# 963  36.488963  127.260274
# 964  36.491848  127.254597
#
# [965 rows x 2 columns]

# %%
for loc in cctv[['위도','경도']].values:
  folium.Marker(loc).add_to(mymap)

# %%
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_336c146aef34f4d25103ab6c0e3e0f55 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_336c146aef34f4d25103ab6c0e3e0f55&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_336c146aef34f4d25103ab6c0e3e0f55 = L.map(
#                 &quot;map_336c146aef34f4d25103ab6c0e3e0f55&quot;,
#                 {
#                     center: [36.6208541, 127.2849716],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_88e5e71373f97ad21fed339d6d53946b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_336c146aef34f4d25103ab6c0e3e0f55);
#
#
#             var marker_fc022668b5423b9370dcd388faaa68ba = L.marker(
#                 [36.6208541, 127.2849716],
#                 {}
#             ).addTo(map_336c146aef34f4d25103ab6c0e3e0f55);
#
#
#         var popup_bad62dc5036317aceadfa1fcab6908b6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7375a3b608a81431c337c6051acd8f97 = $(`&lt;div id=&quot;html_7375a3b608a81431c337c6051acd8f97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hongik Uni&lt;/div&gt;`)[0];
#                 popup_bad62dc5036317aceadfa1fcab6908b6.setContent(html_7375a3b608a81431c337c6051acd8f97);
#
#
#
#         marker_fc022668b5423b9370dcd388faaa68ba.bindPopup(popup_bad62dc5036317aceadfa1fcab6908b6)
#         ;
#
#
#
#
#             var marker_226da01a53e55d72a7010fc6f1d10367 = L.marker(
#                 [36.59252275, 127.2935416668],
#                 {}
#             ).addTo(map_336c146aef34f4d25103ab6c0e3e0f55);
#
#
#             var marker_308a2cf58378cb8d009d6cc1bd6a2ff7 = L.marker(
#                 [36.597449, 127.2933959446],
#                 {}
#             ).addTo(map_336c146aef34f4d25103ab6c0e3e0f55);
#
#
#             var marker_4a21c7ede8ec10d04bcdf2b8da1c48c5 = L.marker(
#                 [36.5979997892, 127.3019097156],
#                 {}
#             ).addTo(map_336c146aef34f4d25103ab6c0e3e0f55);
#
#
#             var marker_f6dead94f7d0676292e2d8eb812a471d = L.marker(
#                 [36.6009460759, 127.2917157181],
#                 {}
#             ).addTo(map_336c146aef34f4d25103ab6c0e3e0f55);
#
#
#             var marker_41e80c910faa41dd1ae223075286b1ce = L.marker(
#                 [36.6010829555, 127.2948510106],
#                 {}
#             ).addTo(map_336c146aef34f4d25103ab6c0e3e0f55);
#
#
#             var marker_02b6e7efae1dde1466825d9409a01952 = L.marker(
#                 [36.602220289, 127.2997049987],
#                 {}
#             ).addTo(map_336c146aef34f4d25103ab6c0e3e0f55);
#
#
#             var marker_4ae2cb49b72035e4b1e43e8c688af9e3 = L.marker(
#                 [36.597762151, 127.2897514958],
#                 {}
#             ).addTo(map_336c146aef34f4d25103ab6c0e3e0f55);
#
#
#             var marker_79e392d44edbe964fee7e5bc588b3c93 = L.marker(
#                 [36.6104768252, 127.2974254002],
#                 {}
#             ).addTo(map_336c146aef34f4d25103ab6c0e3e0f55);
#
#
#             var marker_bf2814aceeef2d6d6fc435e00db76ceb = L.marker(
#                 [36.6029013952, 127.2968866633],
#                 {}
#             ).addTo(map_336c146aef34f4d25103ab6c0e3e0f55);
#
#
#             var marker_ca1737b6948b7645813da2316b644c99 = L.marker(
#                 [36.59522376, 127.2946087628],
#                 {}
#             ).addTo(map_336c146aef34f4d25103ab6c0e3e0f55);
#
#
#             var marker_73a218cfea6394dfbcb284767328b23a = L.marker(
#                 [36.46795278, 127.2793185997],
#                 {}
#             ).addTo(map_336c146aef34f4d25103ab6c0e3e0f55);
#
#
#             var marker_4af0631214a9e85ce7d5baeebc46b625 = L.marker(
#                 [36.5330009811, 127.3676432156],
#                 {}
#             ).addTo(map_336c146aef34f4d25103ab6c0e3e0f55);
#
#
#             var marker_9a8a1e915a93ca27e4639dcc5ce5ebc1 = L.marker(
#                 [36.6704664777, 127.1950249914],
#                 {}
#             ).addTo(map_336c146aef34f4d25103ab6c0e3e0f55);
#
#
#             var marker_4e32659885ac7cbb604041ea28386931 = L.marker(
#                 [36.559265, 127.3229631806],
#                 {}
#             ).addTo(map_336c146aef34f4d25103ab6c0e3e0f55);
#
#
#             var marker_dd6a9e440259193987fd0940de30d4ee = L.marker(
#                 [36.4940293711, 127.1815466636],
#                 {}
#             ).addTo(map_336c146aef34f4d25103ab6c0e3e0f55);
#
#
#             var marker_fa97e0e9a5c03c5869386a48806bbaed = L.marker(
#                 [36.5122318087, 127.3817489168],
#                 {}
#             ).addTo(map_336c146aef

# %%
mymap = folium.Map(location=[36.6208541,127.2849716], zoom_start=11) # 위도, 경도, 축척

for loc in cctv[['위도','경도']].values:
  folium.Marker(loc).add_to(mymap)

mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d88c9be9e7c0bda2440a0f002a4de8b5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d88c9be9e7c0bda2440a0f002a4de8b5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d88c9be9e7c0bda2440a0f002a4de8b5 = L.map(
#                 &quot;map_d88c9be9e7c0bda2440a0f002a4de8b5&quot;,
#                 {
#                     center: [36.6208541, 127.2849716],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6129d8059285b65fa2100c8db4a93fde = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d88c9be9e7c0bda2440a0f002a4de8b5);
#
#
#             var marker_7b72de9a57671db475ffb6ec1cbac70c = L.marker(
#                 [36.59252275, 127.2935416668],
#                 {}
#             ).addTo(map_d88c9be9e7c0bda2440a0f002a4de8b5);
#
#
#             var marker_fa1be29f2a88955361b284d21972cec3 = L.marker(
#                 [36.597449, 127.2933959446],
#                 {}
#             ).addTo(map_d88c9be9e7c0bda2440a0f002a4de8b5);
#
#
#             var marker_509e3ad9e6392b156a2f03aa15166782 = L.marker(
#                 [36.5979997892, 127.3019097156],
#                 {}
#             ).addTo(map_d88c9be9e7c0bda2440a0f002a4de8b5);
#
#
#             var marker_1ac135582fc667cf327c79f223b8ea76 = L.marker(
#                 [36.6009460759, 127.2917157181],
#                 {}
#             ).addTo(map_d88c9be9e7c0bda2440a0f002a4de8b5);
#
#
#             var marker_0ffe1c6c570ae489df4a73df055f6df1 = L.marker(
#                 [36.6010829555, 127.2948510106],
#                 {}
#             ).addTo(map_d88c9be9e7c0bda2440a0f002a4de8b5);
#
#
#             var marker_52184f98a2666f987bcbc836f82be35f = L.marker(
#                 [36.602220289, 127.2997049987],
#                 {}
#             ).addTo(map_d88c9be9e7c0bda2440a0f002a4de8b5);
#
#
#             var marker_12af2952beb8b89fd37a0f269971fde6 = L.marker(
#                 [36.597762151, 127.2897514958],
#                 {}
#             ).addTo(map_d88c9be9e7c0bda2440a0f002a4de8b5);
#
#
#             var marker_f8c7f5facae15b963d4b6eed3a41535a = L.marker(
#                 [36.6104768252, 127.2974254002],
#                 {}
#             ).addTo(map_d88c9be9e7c0bda2440a0f002a4de8b5);
#
#
#             var marker_588d34cd872add193b3b7d26ab05fcbd = L.marker(
#                 [36.6029013952, 127.2968866633],
#                 {}
#             ).addTo(map_d88c9be9e7c0bda2440a0f002a4de8b5);
#
#
#             var marker_80d152cf39e72ff3eca67aa92d327c88 = L.marker(
#                 [36.59522376, 127.2946087628],
#                 {}
#             ).addTo(map_d88c9be9e7c0bda2440a0f002a4de8b5);
#
#
#             var marker_6575157eb20447680e51b64faca20cca = L.marker(
#                 [36.46795278, 127.2793185997],
#                 {}
#             ).addTo(map_d88c9be9e7c0bda2440a0f002a4de8b5);
#
#
#             var marker_1d9cb057c57f3659d8e524d700c641a4 = L.marker(
#                 [36.5330009811, 127.3676432156],
#                 {}
#             ).addTo(map_d88c9be9e7c0bda2440a0f002a4de8b5);
#
#
#             var marker_9a308f5dbe2b158e98e8df6bf9309ab8 = L.marker(
#                 [36.6704664777, 127.1950249914],
#                 {}
#             ).addTo(map_d88c9be9e7c0bda2440a0f002a4de8b5);
#
#
#             var marker_21ef147d7cef6fbe18c83b022da80892 = L.marker(
#                 [36.559265, 127.3229631806],
#                 {}
#             ).addTo(map_d88c9be9e7c0bda2440a0f002a4de8b5);
#
#
#             var marker_2a049dde9b625099e9f95ec3532c6a9f = L.marker(
#                 [36.4940293711, 127.1815466636],
#                 {}
#             ).addTo(map_d88c9be9e7c0bda2440a0f002a4de8b5);
#
#
#             var marker_0582c8f9a086a8473708b73e69a64e2c = L.marker(
#                 [36.5122318087, 127.3817489168],
#                 {}
#             ).addTo(map_d88c9be9e7c0bda2440a0f002a4de8b5);
#
#
#             var marker_a7b3be6ff2d86c6e47c3ba4de18bd9c8 = L.marker(
#                 [36.508169935, 127.2200582087],
#                 {}
#             ).addTo(map_d88c9be9e7c0bda2440a0f002a4de8b5);
#
#
#             var marker_5196d3652c513232b1e4c5cb81cee803 = L.marker(
#                 [36.530812, 127.3676504791],
#                 {}
#             ).addTo(map_d88c9be9e7c0bda2440a0f002a4de8b5);
#
#
#             var marker_594b2d4c78fef62cddf2884bb8c1979c = L.marker(
#                 [36.716996121, 127.1563725251],
#                 {}
#             ).addTo(map_d88c9be9e7c0bda2440a0f002a4de8b5);
#
#
#             var marker_495b827b5ae73d5d904ae2ae3d07abde = L.marker(
#                 [36.4581966121, 127.2686941012],

# %%
light = pd.read_csv('https://raw.githubusercontent.com/aidalabs/Lectures/master/LectureFiles/dataset/Daejeon_Traffic_Light_20210303.csv', encoding='cp949')
light.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21526 entries, 0 to 21525
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   관리번호    21526 non-null  int64
#  1   주소      21526 non-null  object
#  2   교차로명    21388 non-null  object
#  3   교차로번호   21388 non-null  float64
#  4   설치일자    21345 non-null  object
#  5   신호등 종류  21526 non-null  object
#  6   신호등 재질  21526 non-null  object
#  7   신호등 전구  21526 non-null  object
#  8   경도      21526 non-null  float64
#  9   위도      21526 non-null  float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 1.6+ MB

# %%
mymap = folium.Map(location=[36.353617,127.3690643], zoom_start=20)

for loc in light[['위도','경도','교차로명']].values:

  if loc[2] == '갈마네거리':
        folium.Marker(loc[0:2]).add_to(mymap)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3511177efa3c0761cc5bfeb2e418584f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3511177efa3c0761cc5bfeb2e418584f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3511177efa3c0761cc5bfeb2e418584f = L.map(
#                 &quot;map_3511177efa3c0761cc5bfeb2e418584f&quot;,
#                 {
#                     center: [36.353617, 127.3690643],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 20,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c33fe97d2ba651a80b29a3c02b5c92db = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3511177efa3c0761cc5bfeb2e418584f);
#
#
#             var marker_04912de03339502d1424e559805cb840 = L.marker(
#                 [36.35347969, 127.3680609],
#                 {}
#             ).addTo(map_3511177efa3c0761cc5bfeb2e418584f);
#
#
#             var marker_613d0e43537b19e85991a21a65ee97a8 = L.marker(
#                 [36.35350965, 127.3680912],
#                 {}
#             ).addTo(map_3511177efa3c0761cc5bfeb2e418584f);
#
#
#             var marker_6b8398117286f67b620a7e3a8250887f = L.marker(
#                 [36.35340712, 127.3679883],
#                 {}
#             ).addTo(map_3511177efa3c0761cc5bfeb2e418584f);
#
#
#             var marker_9410cc1e9ce75868269a59985835074a = L.marker(
#                 [36.35358942, 127.3679617],
#                 {}
#             ).addTo(map_3511177efa3c0761cc5bfeb2e418584f);
#
#
#             var marker_69553cdccccce6d3a2fda3c4fc8dc702 = L.marker(
#                 [36.35372128, 127.3681283],
#                 {}
#             ).addTo(map_3511177efa3c0761cc5bfeb2e418584f);
#
#
#             var marker_21f5ffe53ed23a8da8f5fd0be50a05b9 = L.marker(
#                 [36.35375696, 127.36817],
#                 {}
#             ).addTo(map_3511177efa3c0761cc5bfeb2e418584f);
#
#
#             var marker_49495214b597266d69abc472c615f883 = L.marker(
#                 [36.35369541, 127.3681016],
#                 {}
#             ).addTo(map_3511177efa3c0761cc5bfeb2e418584f);
#
#
#             var marker_5f374544f274698ee6e478feedc6393a = L.marker(
#                 [36.35271946, 127.3687951],
#                 {}
#             ).addTo(map_3511177efa3c0761cc5bfeb2e418584f);
#
#
#             var marker_0b96c78916f69c60bdfc493a69ea10f4 = L.marker(
#                 [36.35273454, 127.3687493],
#                 {}
#             ).addTo(map_3511177efa3c0761cc5bfeb2e418584f);
#
#
#             var marker_8f0e5118034c3b3a528727db4442194c = L.marker(
#                 [36.35312944, 127.3685363],
#                 {}
#             ).addTo(map_3511177efa3c0761cc5bfeb2e418584f);
#
#
#             var marker_f20919ae67c147603216eae239fbb76d = L.marker(
#                 [36.35316152, 127.3685694],
#                 {}
#             ).addTo(map_3511177efa3c0761cc5bfeb2e418584f);
#
#
#             var marker_dcb6474ce5cc3a72a1a6a5a90f01135f = L.marker(
#                 [36.35305717, 127.3684991],
#                 {}
#             ).addTo(map_3511177efa3c0761cc5bfeb2e418584f);
#
#
#             var marker_643005b60d9a0604fbfa3cc80d6bcd8e = L.marker(
#                 [36.35337228, 127.3688663],
#                 {}
#             ).addTo(map_3511177efa3c0761cc5bfeb2e418584f);
#
#
#             var marker_dfb7566e4c2fd4c288aa3bf9f2139be2 = L.marker(
#                 [36.35337874, 127.3689281],
#                 {}
#             ).addTo(map_3511177efa3c0761cc5bfeb2e418584f);
#
#
#             var marker_371a7eb6129cb60bc237c1badd6775b0 = L.marker(
#                 [36.35337558, 127.368953],
#                 {}
#             ).addTo(map_3511177efa3c0761cc5bfeb2e418584f);
#
#
#             var marker_bdc301635d4f3debb174b29d739afcb1 = L.marker(
#                 [36.35307538, 127.3690453],
#                 {}
#             ).addTo(map_3511177efa3c0761cc5bfeb2e418584f);
#
#
#             var marker_bc6d78f1e4e814f2d58c58cd63550be9 = L.marker(
#                 [36.35304308, 127.369013],
#                 {}
#             ).addTo(map_3511177efa3c0761cc5bfeb2e418584f);
#
#
#             var marker_5907a9e4946fb5e78a283bab59e07f58 = L.marker(
#                 [36.35272849, 127.3688555],
#                 {}
#             ).addTo(map_3511177efa3c0761cc5bfeb2e418584f);
#
#
#             var marker_c434c44573b165b9f13889cbe23412bd = L.marker(
#                 [36.35276082, 127.3686938],
#                 {}
#             ).addTo(map_3511177efa3c0761cc5bfeb2e418584f);
#
#
#             var marker_8bd7e63b9e8b7251202c5ff52dd30ef7 = L.marker(
#                 [36.35274706, 127.3687377],
#                 {}
#             ).addTo(map_3511177efa3c0761cc5bfeb2e418584f);

# %%
trans = pd.read_csv('https://raw.githubusercontent.com/aidalabs/Lectures/master/LectureFiles/dataset/Pohang_RSE_20200831.csv', encoding='cp949')

mymap = folium.Map(location=[(trans['위도'].max() + trans['위도'].min())/2,(trans['경도'].max() + trans['경도'].min()) / 2], zoom_start=12)
for loc in trans[['위도', '경도', '시설물 위치']].values:
  folium.Marker(loc[0:2], popup=loc[2]).add_to(mymap)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_48051a89339e344c07552f69986c84fe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_48051a89339e344c07552f69986c84fe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_48051a89339e344c07552f69986c84fe = L.map(
#                 &quot;map_48051a89339e344c07552f69986c84fe&quot;,
#                 {
#                     center: [36.094207105, 129.3869813],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b5a49d2361ee2e019f42f135045b37c7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_48051a89339e344c07552f69986c84fe);
#
#
#             var marker_56eeee0dfc31461cbbfefede48f0cab0 = L.marker(
#                 [36.08965283, 129.3816124],
#                 {}
#             ).addTo(map_48051a89339e344c07552f69986c84fe);
#
#
#         var popup_0fb78b638b64c9b52832a1bed88c62c0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d7dbcd998fb68ee38bf2a1f4369fb739 = $(`&lt;div id=&quot;html_d7dbcd998fb68ee38bf2a1f4369fb739&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;LH휴먼시아&lt;/div&gt;`)[0];
#                 popup_0fb78b638b64c9b52832a1bed88c62c0.setContent(html_d7dbcd998fb68ee38bf2a1f4369fb739);
#
#
#
#         marker_56eeee0dfc31461cbbfefede48f0cab0.bindPopup(popup_0fb78b638b64c9b52832a1bed88c62c0)
#         ;
#
#
#
#
#             var marker_8c34a7656993d0ed1e0d6859f69ff463 = L.marker(
#                 [36.08616372, 129.3970101],
#                 {}
#             ).addTo(map_48051a89339e344c07552f69986c84fe);
#
#
#         var popup_2f22360a6cbca940a1f54f16bcb71a54 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ba5c628b696c7920433bc872d69e0766 = $(`&lt;div id=&quot;html_ba5c628b696c7920433bc872d69e0766&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;e-편한세상&lt;/div&gt;`)[0];
#                 popup_2f22360a6cbca940a1f54f16bcb71a54.setContent(html_ba5c628b696c7920433bc872d69e0766);
#
#
#
#         marker_8c34a7656993d0ed1e0d6859f69ff463.bindPopup(popup_2f22360a6cbca940a1f54f16bcb71a54)
#         ;
#
#
#
#
#             var marker_bf39ba229e6e3e47d338733859911202 = L.marker(
#                 [35.99264086, 129.3432179],
#                 {}
#             ).addTo(map_48051a89339e344c07552f69986c84fe);
#
#
#         var popup_60c943e6d8533c7f40a0a2c65422cc5c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_88eed162bd00bd98ce471fa1d7a2069f = $(`&lt;div id=&quot;html_88eed162bd00bd98ce471fa1d7a2069f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;택전사거리&lt;/div&gt;`)[0];
#                 popup_60c943e6d8533c7f40a0a2c65422cc5c.setContent(html_88eed162bd00bd98ce471fa1d7a2069f);
#
#
#
#         marker_bf39ba229e6e3e47d338733859911202.bindPopup(popup_60c943e6d8533c7f40a0a2c65422cc5c)
#         ;
#
#
#
#
#             var marker_0da2c789e211344f79d2a630d12ac245 = L.marker(
#                 [35.98976893, 129.4335794],
#                 {}
#             ).addTo(map_48051a89339e344c07552f69986c84fe);
#
#
#         var popup_3fb231c5e857d54038fcd0f16319bed8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_504222b4014171953664a6789c7ac6ca = $(`&lt;div id=&quot;html_504222b4014171953664a6789c7ac6ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;공항삼거리&lt;/div&gt;`)[0];
#                 popup_3fb231c5e857d54038fcd0f16319bed8.setContent(html_504222b4014171953664a6789c7ac6ca);
#
#
#
#         marker_0da2c789e211344f79d2a630d12ac245.bindPopup(popup_3fb231c5e857d54038fcd0f16319bed8)
#         ;
#
#
#
#
#             var marker_d20cf28113e8550ec7423d772e69d4bb = L.marker(
#                 [36.04016508, 129.3700939],
#                 {}
#             ).addTo(map_48051a89339e344c07552f69986c84fe);
#
#
#         var popup_275c8068b1de2db682423e68576faa34 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a07d7b1771fe9833ca4607402dffe239 = $(`&lt;div id=&quot;html_a07d7b1771fe9833ca4607402dffe239&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;동빈큰사거리 서편&lt;/div&gt;`)[0];
#                 popup_275c8068b1de2db682423e68576faa34.setContent(html_a07d7b1771fe9833ca4607402dffe239);
#
#
#
#         marker_d20cf28113e8550ec7423d772e69d4bb.bindPopup(popup_275c8068b1de2db682423e68576faa34)
#         ;
#
#
#
#
#             var marker_39b6bfabffb40af9c1999162af644b68 = L.marker(
#                 [36.10207053, 129.367977],
#                 {}
